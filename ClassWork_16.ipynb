# %%
class Employee: 
  def __init__ (self, surname, name, e_mail, phone, one_day_salary, work_days): 
  self.one_day_salary = one_day_salary 
  self.work_days = work_days
  pass

  def work (self):
    return ('I come to office')
    self.work = work
    pass 

  def check_salary (self, Employee): 
    return (check_salary)
    check_salary = self.one_day_salary * self.work_days
    print (check_salary)
    pass 

class Recruiter (Employee): 
  def __init__ Recruiter_answer (self): 
    super().__init__(self.work)
    print (self.work, 'and start hiring.')


class Programmer (Employee): 
  def __init__ Programmer_answer (self): 
    super().__init__(self.work)
    print (self.work, 'and start coding.')

# %%
 def check_salary (salary): 
    return (salary)
 one_day_salary = int(input('Insert one day salary, USD:    '))
 work_days = int(input('Insert period in workdays:   '))
 salary = one_day_salary * work_days
 print ('Your salary, USD:', salary)
# Out:
# Insert one day salary, USD:    67
# Insert period in workdays:   150
# Your salary, USD: 10050
